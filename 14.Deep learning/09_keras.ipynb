# %% [markdown]
# ### Tensorflow
# >Strona biblioteki: [https://www.tensorflow.org/](https://www.tensorflow.org/)
# >Dokumentacja: [https://www.tensorflow.org/api_docs](https://www.tensorflow.org/api_docs)
# >
# >Szybko rozwijająca się biblioteka do uczenia maszynowego i uczenia głębokiego rozwijana przez Google.
# >
# >Aby zainstalować bibliotekę tensorflow, użyj polecenia poniżej:
# ```
# pip install tensorflow
# ```
#
# ### Keras
# >Strona biblioteki: [https://keras.io/](https://keras.io/)
# >
# >Wysokopoziomowy interfejs do budowy sieci neuronowych. Działa zarówno na Tensorflow, Theano oraz CNTK.
# >
# >Aby zainstalować bibliotekę keras, użyj polecenia poniżej:
# ```
# pip install keras
# ```

# %% [markdown]
# ### Model sekwencjny (Sequential Model):
# 1. [Wprowadzenie - pierwszy model](#a0)
# 2. [Funkcje aktywacji](#a1)
# 3. [Kompilacja modelu](#a2)
# 4. [Trenowanie modelu](#a3)
# 5. [Przykład - klasyfikacja binarna](#a4)
# 6. [Przykład - klasyfikacja wieloklasowa](#a5)
# 7. [Przykład - regresja](#a6)
#
#
#
# Załadowanie biblioteki tensorflow

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import plotly.express as px
tf.__version__
# Out:
# Bad value in file PosixPath('/Users/tomasz/.matplotlib/stylelib/company.mplstyle'), line 3 ("axes.prop_cycle: cycler('color', ['#123D98', '#C21E3C', '#E2A713', '#00AEEF', '#7F3F98'])"): Key axes.prop_cycle: "cycler('color', ['" is not a valid cycler construction: EOL while scanning string literal (<unknown>, line 1)
# Bad value in file PosixPath('/Users/tomasz/.matplotlib/stylelib/company.mplstyle'), line 6 ('grid.color: #e0e0e0'): Key grid.color: '' does not look like a color arg
# '2.16.2'

# %% [markdown]
# ### <a name='a0'></a>Wprowadzenie - pierwszy model
# Model sekwencyjny to nic innego jak liniowy stos warstw.

# %%
# utworzenie instancji klasy Sequential
from tensorflow.keras.models import Sequential

model = Sequential()
print(model)
# Out:
# <Sequential name=sequential, built=False>

# %% [markdown]
# Podstawowym elementem składowym modelu są warstwy. Aby dodać najbardziej standardową warstwę - warstwę gęsto połączoną należy użyć warstwy **Dense**. Aby dodać warstwę do modelu należy użyć metody *.add()*

# %%
from tensorflow.keras.layers import Dense

model.add(Dense(units=4, input_shape=(10,)))
# Out:
# 2025-12-19 14:32:35.431222: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2025-12-19 14:32:35.431410: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-12-19 14:32:35.431420: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-12-19 14:32:35.431634: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-19 14:32:35.431653: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# Wyświetlenie podsumowania modelu: metoda *.summary()*

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            44 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44 (176.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Dodanie kolejnej warstwy

# %%
model.add(Dense(units=2))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            44 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54 (216.00 B)
#  Trainable params: 54 (216.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### <a name='a2'></a>Kompilacja modelu
# Przed rozpoczęciem trenowania sieci należy odpowiednio skonfigurować proces uczenia. W tym kroku określamy:
# * rodzaj optymalizatora ([Keras - Optymalizatory](https://keras.io/optimizers/))
# * funkcję straty ([Keras - Funkcje Straty](https://keras.io/losses/))
# * metryki, które będziemy obserwować podczas trenowania sieci ([Keras - Metryki](https://keras.io/metrics/))

# %%
# klasyfikacja binarna
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# klasyfikacja wieloklasowa
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# regresja
model.compile(optimizer='rmsprop',
              loss='mse')

# %% [markdown]
# ### <a name='a3'></a>Trenowanie modelu
# Za dane wejściowe do modelu należy przekazać Numpy arrays:
# * **epochs** - krotność przejścia danych przez sieć w procesie uczenia
# * **batch_size** - rozmiar wsadu po którym następuje aktualizacja wag
# * **validation_split** - część danych treningowych, które zostaną wykorzystane jako zbiór walidacyjny
# * **validation_data** - (x_val, y_val) - dane wykorzystane do walidacji modelu

# %%
# model.fit(data, labels, epochs=10, batch_size=32)
# model.fit(data, labels, epochs=10, batch_size=32, validation_split=0.2)
# model.fit(data, labels, epochs=10, batch_size=32, validation_data=(x_val, y_val))

# %% [markdown]
# ### <a name='a4'></a> Przykład - klasyfikacja binarna

# %%
data = np.random.randn(10000, 150)
labels = np.random.randint(2, size=(10000, 1))

print(data.shape)
print(labels.shape)
# Out:
# (10000, 150)
# (10000, 1)

# %%
data[:3]
# Out:
# array([[-6.01029003e-01,  1.43593486e+00, -5.27046698e-01,
#          1.06017250e+00, -1.27942794e+00,  1.02900833e+00,
#         -1.23458856e+00,  1.29336258e+00,  2.13641715e-01,
#          1.32829925e+00, -1.26469124e+00, -1.81091625e+00,
#          8.97070790e-01, -8.37297612e-01,  1.50638807e+00,
#          6.42234148e-01, -2.45650337e-01,  1.34210864e+00,
#         -2.08651195e+00, -7.24135174e-02,  8.37449064e-01,
#          2.81329927e-01, -9.34999417e-01, -9.60839437e-01,
#          3.49586635e-01,  1.24658827e+00,  2.07796879e-01,
#          9.08540468e-03, -1.14801758e-01,  1.88777404e+00,
#          2.96356739e-01,  1.29095056e+00, -1.72489023e+00,
#          2.64683175e+00,  4.12198774e-01, -3.58274487e-01,
#         -6.01044745e-01,  5.64880642e-02,  1.26004235e+00,
#          7.65870903e-01, -9.14330583e-01,  2.46983043e-01,
#         -7.75202722e-01,  2.77477387e-02, -1.08360051e+00,
#          3.41527517e-01, -2.35154680e-01, -7.16210513e-01,
#          7.91145198e-01,  9.73529747e-01, -2.71685370e+00,
#          1.59966972e+00,  2.06238069e+00,  8.34089133e-01,
#          2.48931303e-01, -1.25581965e+00, -9.73084634e-01,
#         -1.86336834e+00, -8.66873478e-01, -1.09894853e+00,
#         -3.78037212e-01,  3.13706847e-01,  9.01917166e-01,
#          1.56861732e+00, -1.44780117e+00,  1.13091633e+00,
#          5.48679916e-01,  2.15958635e+00,  1.17158871e+00,
#          6.75133309e-01, -7.51257985e-01,  4.33867595e-01,
#         -6.54537706e-01, -8.93503549e-02,  5.06609811e-01,
#          9.81741859e-01,  8.34175128e-01, -2.23337321e-01,
#         -1.79110290e-01,  6.11066155e-02,  3.85133590e-01,
#          7.89866295e-01, -6.24021253e-01, -5.63168108e-01,
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5286 - loss: 0.6961
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5422 - loss: 0.6924
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5355 - loss: 0.6947
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5421 - loss: 0.6912
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5227 - loss: 0.6945
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5306 - loss: 0.6932
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5330 - loss: 0.6940
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5258 - loss: 0.6946
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5424 - loss: 0.6909
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5403 - loss: 0.6897
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5339 - loss: 0.6921
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5365 - loss: 0.6924
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5354 - loss: 0.6927
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5434 - loss: 0.6917
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5323 - loss: 0.6930
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5388 - loss: 0.6915
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5376 - loss: 0.6930

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(150,)))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(data, labels, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4848 - loss: 0.8767 - val_accuracy: 0.4890 - val_loss: 0.7127
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5393 - loss: 0.6998 - val_accuracy: 0.4995 - val_loss: 0.7124
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5393 - loss: 0.6963 - val_accuracy: 0.4985 - val_loss: 0.7122
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5376 - loss: 0.6942 - val_accuracy: 0.5000 - val_loss: 0.7128
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5380 - loss: 0.6975 - val_accuracy: 0.4955 - val_loss: 0.7162
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5343 - loss: 0.6971 - val_accuracy: 0.4890 - val_loss: 0.7118
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5317 - loss: 0.6962 - val_accuracy: 0.4935 - val_loss: 0.7142
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5380 - loss: 0.6937 - val_accuracy: 0.4950 - val_loss: 0.7115
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5416 - loss: 0.6950 - val_accuracy: 0.4915 - val_loss: 0.7094
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5301 - loss: 0.6958 - val_accuracy: 0.4990 - val_loss: 0.7073
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5486 - loss: 0.6922 - val_accuracy: 0.5080 - val_loss: 0.7046
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5358 - loss: 0.6930 - val_accuracy: 0.4895 - val_loss: 0.7102
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5384 - loss: 0.6935 - val_accuracy: 0.4910 - val_loss: 0.7097
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5359 - loss: 0.6941 - val_accuracy: 0.4870 - val_loss: 0.7098
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5430 - loss: 0.6911 - val_accuracy: 0.4935 - val_loss: 0.7103
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5520 - loss: 0.6911 - val_accuracy: 0.4850 - val_loss: 0.7096
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5273 - loss: 0.6948 - val_accuracy: 0.4855 - val_loss: 0.7113
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5347 - loss: 0.6942 - val_accuracy: 0.4835 - val_loss: 0.7086
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5400 - loss: 0.6919 - val_accuracy: 0.4865 - val_loss: 0.7100
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5434 - loss: 0.6917 - val_accuracy: 0.4855 - val_loss: 0.7087

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(150,)))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(data, labels, epochs=20, batch_size=32, validation_split=0.2, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 9
#       3 model.add(Dense(1, activation='sigmoid'))
#       5 model.compile(optimizer='rmsprop',
#       6               loss='binary_crossentropy',
#       7               metrics=['accuracy'])
# ----> 9 history = model.fit(data, labels, epochs=20, batch_size=32, validation_split=0.2, verbose=0)
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:375, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     373 callbacks.on_epoch_begin(epoch)
#     374 with epoch_iterator.catch_stop_iteration():
# --> 375     for step, iterator in epoch_iterator:
#     376         callbacks.on_train_batch_begin(step)
#     377         logs = self.train_function(iterator)
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:740, in TFEpochIterator.__next__(self)
#     739 def __next__(self):
# --> 740     return next(self._epoch_iterator)
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/keras/src/trainers/epoch_iterator.py:111, in EpochIterator._enumerate_iterator(self)
#     109 if steps_per_epoch > 0:
#     110     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 111         self._current_iterator = iter(self._get_iterator())
#     112         self._steps_seen = 0
#     113     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:705, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     701   if (components is not None or element_spec is not None):
#     702     raise ValueError(
#     703         "When `dataset` is provided, `element_spec` and `components` must "
#     704         "not be specified.")
# --> 705   self._create_iterator(dataset)
#     707 self._get_next_call_count = 0
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py:744, in OwnedIterator._create_iterator(self, dataset)
#     741   assert len(fulltype.args[0].args[0].args) == len(
#     742       self._flat_output_types)
#     743   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 744 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/Desktop/ML_DL_Python_Comarch/.venv/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
history = model.fit(data, labels, epochs=20, batch_size=32, validation_split=0.2, verbose=0)

# %%
metrics = history.history
metrics
# Out:
# {'accuracy': [0.5301250219345093,
#   0.5339999794960022,
#   0.5403749942779541,
#   0.531374990940094,
#   0.5323749780654907,
#   0.5360000133514404,
#   0.5364999771118164,
#   0.5337499976158142,
#   0.5335000157356262,
#   0.5368750095367432,
#   0.5394999980926514,
#   0.5387499928474426,
#   0.5451250076293945,
#   0.5398749709129333,
#   0.5372499823570251,
#   0.5388749837875366,
#   0.5463749766349792,
#   0.5411249995231628,
#   0.5427500009536743,
#   0.5446249842643738],
#  'loss': [0.6944161653518677,
#   0.6938069462776184,
#   0.6933324933052063,
#   0.692718505859375,
#   0.6934031844139099,
#   0.6929741501808167,
#   0.6925607323646545,
#   0.6922082901000977,
#   0.6923058032989502,
#   0.6920173168182373,
#   0.6918381452560425,
#   0.6915864944458008,
#   0.6916273236274719,
#   0.6911793351173401,
#   0.6912327408790588,
#   0.6911919713020325,
#   0.6906867027282715,
#   0.6905798316001892,
#   0.6910833716392517,
#   0.6897892951965332],
#  'val_accuracy': [0.4950000047683716,
#   0.48750001192092896,
#   0.49149999022483826,
#   0.492000013589859,
#   0.4975000023841858,
#   0.49050000309944153,
#   0.4975000023841858,
#   0.4855000078678131,
#   0.4925000071525574,
#   0.48350000381469727,
#   0.503000020980835,
#   0.4880000054836273,
#   0.503000020980835,
#   0.4945000112056732,
#   0.48649999499320984,
#   0.49950000643730164,
#   0.5005000233650208,
#   0.48649999499320984,
#   0.4970000088214874,
#   0.49799999594688416],
#  'val_loss': [0.7095910310745239,
#   0.708363950252533,
#   0.7072382569313049,
#   0.7078490853309631,
#   0.7077796459197998,
#   0.7068488597869873,
#   0.7055839896202087,
#   0.7062640190124512,
#   0.7062562108039856,
#   0.708220899105072,
#   0.7097315788269043,
#   0.7065727114677429,
#   0.7052132487297058,
#   0.7048238515853882,
#   0.7064828872680664,
#   0.7080110907554626,
#   0.7081829309463501,
#   0.709440290927887,
#   0.7062885165214539,
#   0.7069271802902222]}

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(150,)))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(data, labels, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

# %%
test_data = np.random.randn(5, 150)
test_labels = np.random.randint(2, size=(5, 1))

# %%
model.predict(test_data)

# %%
model.predict_proba(test_data)

# %%
model.predict_classes(test_data)

# %% [markdown]
# ### <a name='a5'></a> Przykład - klasyfikacja wieloklasowa

# %%
data = np.random.random((10000, 150))
labels = np.random.randint(10, size=(10000, 1))

# %%
print(data.shape)
print(labels.shape)

# %%
labels[:10]

# %%
from tensorflow.keras.utils import to_categorical
labels = to_categorical(labels, num_classes=10)
labels

# %%
labels[1]

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(150,)))
model.add(Dense(units=10, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(data, labels, batch_size=32, epochs=30, validation_split=0.2)

# %%
test_data = np.random.random((10, 150))

model.predict(test_data)

# %%
model.predict_classes(test_data)

# %% [markdown]
# ### <a name='a6'></a> Przykład - regresja

# %%
data = np.random.random((10000, 150))
labels = 50 * np.random.random(10000)

# %%
labels[:10]

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(150,)))
model.add(Dense(units=1))

model.compile(optimizer='rmsprop',
              loss='mse')

model.fit(data, labels, epochs=30, batch_size=32, validation_split=0.2)

# %%
model = Sequential()
model.add(Dense(units=32, activation='relu', input_shape=(150,)))
model.add(Dense(units=1))

model.compile(optimizer='rmsprop',
              loss='mae',
              metrics=['mse'])

model.fit(data, labels, epochs=10, batch_size=32, validation_split=0.2)

# %%
test_data = np.random.random((10, 150))

model.predict(test_data)
