# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: requests>=2.31 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.2/949.2 kB 12.9 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tomasz/0.Szkolenia/zadania - analiza NOWE/.venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.5.0)
# Downloading yfinance-0.2.66-py2.py3-none-any.whl (123 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 32.5 MB/s  0:00:00
# Downloading cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Downloading frozendict-2.4.6-py313-none-any.whl (16 kB)
# Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl (426 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15636 sha256=38e31d1c9ff7d802d2a1581b580ab498a621995cab898b9cb5e363e521046150
#   Stored in directory: /Users/tomasz/Library/Caches/pip/wheels/1e/df/0f/e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.18.2-cp313-cp313-macosx_10_13_universal2.whl size=432878 sha256=e4b1697754f81a7f800d8723664579620d69b34ae2ccf6876d1ab51bbfa4ab67
#   Stored in directory: /Users/tomasz/Library/Caches/pip/wheels/1c/48/cc/00b7d0e7defa21a58915654917c89eaedd32a6e614d8e4ad92
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, typing-extensions, soupsieve, pycparser, protobuf, frozendict, cffi, beautifulsoup4, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [yfinance]/12 [yfinance]]
# Successfully installed beautifulsoup4-4.14.2 cffi-2.0.0 curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 protobuf-6.32.1 pycparser-2.23 soupsieve-2.8 typing-extensions-4.15.0 websockets-15.0.1 yfinance-0.2.66

# %% [markdown]
# Polecenie !pip install pandas_datareader zainstaluje bibliotekę w aktywnym środowisku Pythona, w którym jest wykonywane. Jeśli przed instalacją aktywowałeś środowisko wirtualne (np. za pomocą venv lub conda), to pakiet zostanie zainstalowany właśnie tam. W przeciwnym razie, gdy środowisko wirtualne nie jest aktywne, instalacja odbywa się w domyślnym (globalnym) środowisku Pythona.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()
np.__version__
# Out:
# '2.2.5'

# %% [markdown]
# Funkcja _fetch_financial_data()_ pobiera dane dotyczące notowań spółek giełdowych. Będzie wykorzystywana w poniższych ćwiczeniach. Aby pobrać dane konkretnej spółki należy przekazać odpowiedni ticker (symbol) spółki.
#
# Kilka przykładowych tickerów spółek:
# * AMZN - Amazon
# * GOOGL - Google
# * MSFT - Microsoft
# * AAPL - Apple
# * NKE - Nike
# * WMT - Walmart

# %%
import yfinance as yf

def fetch_financial_data(company='AMZN'):
    """
    Funkcja pobiera notowania giełdowe z yfinance.
    """
    ticker = yf.Ticker(company)
    data = ticker.history(period='max')
    return data

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 41
# Wykorzystując funkcję _fetch_financial_data()_ pobierz notowania dla spółki Google (Alphabet) i przypisz do zmiennej _google_. Wyświetl obiekt _google_.

# %%
google = fetch_financial_data('GOOGL')
google
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2004-08-19 00:00:00-04:00    2.485361    2.586266    2.384952    2.493811
# 2004-08-20 00:00:00-04:00    2.510463    2.711032    2.497788    2.691894
# 2004-08-23 00:00:00-04:00    2.752538    2.820388    2.710286    2.718985
# 2004-08-24 00:00:00-04:00    2.764715    2.773663    2.574088    2.606397
# 2004-08-25 00:00:00-04:00    2.608635    2.684190    2.581793    2.634482
# ...                               ...         ...         ...         ...
# 2025-11-12 00:00:00-05:00  291.679993  292.010010  283.690002  286.709991
# 2025-11-13 00:00:00-05:00  282.339996  282.839996  277.239990  278.570007
# 2025-11-14 00:00:00-05:00  271.410004  278.559998  270.700012  276.410004
# 2025-11-17 00:00:00-05:00  285.779999  293.950012  283.570007  285.019989
# 2025-11-18 00:00:00-05:00  287.920013  288.799988  278.200012  284.279999
#
#                               Volume  Dividends  Stock Splits
# Date
# 2004-08-19 00:00:00-04:00  893181924        0.0           0.0
# 2004-08-20 00:00:00-04:00  456686856        0.0           0.0
# 2004-08-23 00:00:00-04:00  365122512        0.0           0.0
# 2004-08-24 00:00:00-04:00  304946748        0.0           0.0
# 2004-08-25 00:00:00-04:00  183772044        0.0           0.0
# ...                              ...        ...           ...
# 2025-11-12 00:00:00-05:00   24829900        0.0           0.0
# 2025-11-13 00:00:00-05:00   29494000        0.0           0.0
# 2025-11-14 00:00:00-05:00   31647200        0.0           0.0
# 2025-11-17 00:00:00-05:00   52670200        0.0           0.0
# 2025-11-18 00:00:00-05:00   49089600        0.0           0.0
#
# [5348 rows x 7 columns]

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 42
# Wyświetl podstawowe informacje na temat obiektu _google_.

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5348 entries, 2004-08-19 00:00:00-04:00 to 2025-11-18 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          5348 non-null   float64
#  1   High          5348 non-null   float64
#  2   Low           5348 non-null   float64
#  3   Close         5348 non-null   float64
#  4   Volume        5348 non-null   int64
#  5   Dividends     5348 non-null   float64
#  6   Stock Splits  5348 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 334.2 KB

# %% [markdown]
# Wyświetl podstawowe statystyki o obiekcie _google_.

# %%
google.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  5348.000000  5348.000000  5348.000000  5348.000000  5.348000e+03
# mean     53.757876    54.339002    53.189569    53.780071  1.123112e+08
# std      54.389709    55.023102    53.796498    54.435192  1.447769e+08
# min       2.465229     2.528606     2.384952     2.485610  9.312000e+06
# 25%      13.286925    13.397958    13.129912    13.272447  3.029150e+07
# 50%      29.185207    29.370714    28.964477    29.169618  5.295849e+07
# 75%      74.128607    74.988298    73.440841    74.347593  1.327641e+08
# max     291.679993   293.950012   287.320007   291.309998  1.643023e+09
#
#          Dividends  Stock Splits
# count  5348.000000   5348.000000
# mean      0.000228      0.004113
# std       0.006809      0.274842
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       0.210000     20.000000

# %% [markdown]
# Zwróć uwagę na precyzję zapisu poszczególnych statystyk.
# Warto ustawić odpowiednie opcje biblioteki _pandas_, tak aby wyświetlać dane z dokładnością do dwóch miejsc po przecinku.
#
# __Wskazówka:__
# Użyj funkcji:
#
# - pd.set_option("display.precision", 2)
# - pd.options.display.float_format = '{:.2f}'.format
#
# __Wskazówka:__
# https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html

# %%
pd.set_option("display.precision", 2)
google.describe()
# Out:
#           Open     High      Low    Close    Volume  Dividends  Stock Splits
# count  5348.00  5348.00  5348.00  5348.00  5.35e+03   5.35e+03      5.35e+03
# mean     53.76    54.34    53.19    53.78  1.12e+08   2.28e-04      4.11e-03
# std      54.39    55.02    53.80    54.44  1.45e+08   6.81e-03      2.75e-01
# min       2.47     2.53     2.38     2.49  9.31e+06   0.00e+00      0.00e+00
# 25%      13.29    13.40    13.13    13.27  3.03e+07   0.00e+00      0.00e+00
# 50%      29.19    29.37    28.96    29.17  5.30e+07   0.00e+00      0.00e+00
# 75%      74.13    74.99    73.44    74.35  1.33e+08   0.00e+00      0.00e+00
# max     291.68   293.95   287.32   291.31  1.64e+09   2.10e-01      2.00e+01

# %% [markdown]
# __Dodatkowo:__
# Poniższe ustawienie stłumi także notację wykładniczą (patrz kolumna _Volume_).

# %%
pd.options.display.float_format = '{:.2f}'.format
google.describe()
# Out:
#          Open    High     Low   Close        Volume  Dividends  Stock Splits
# count 5348.00 5348.00 5348.00 5348.00       5348.00    5348.00       5348.00
# mean    53.76   54.34   53.19   53.78  112311214.61       0.00          0.00
# std     54.39   55.02   53.80   54.44  144776869.52       0.01          0.27
# min      2.47    2.53    2.38    2.49    9312000.00       0.00          0.00
# 25%     13.29   13.40   13.13   13.27   30291500.00       0.00          0.00
# 50%     29.19   29.37   28.96   29.17   52958492.00       0.00          0.00
# 75%     74.13   74.99   73.44   74.35  132764103.00       0.00          0.00
# max    291.68  293.95  287.32  291.31 1643023332.00       0.21         20.00

# %% [markdown]
# Zbuduj wykres ceny zamknięcia (_Close_) dla obiektu _google_.

# %%
google['Close'].plot();

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 43
# Zamień indeks _Date_ na kolumnę. Przypisz trwale zmiany do zniennej _google_.

# %%
google = google.reset_index()
google
# Out:
#                           Date   Open   High    Low  Close     Volume  \
# 0    2004-08-19 00:00:00-04:00   2.49   2.59   2.38   2.49  893181924
# 1    2004-08-20 00:00:00-04:00   2.51   2.71   2.50   2.69  456686856
# 2    2004-08-23 00:00:00-04:00   2.75   2.82   2.71   2.72  365122512
# 3    2004-08-24 00:00:00-04:00   2.76   2.77   2.57   2.61  304946748
# 4    2004-08-25 00:00:00-04:00   2.61   2.68   2.58   2.63  183772044
# ...                        ...    ...    ...    ...    ...        ...
# 5309 2025-09-25 00:00:00-04:00 244.40 246.49 240.74 245.79   31020400
# 5310 2025-09-26 00:00:00-04:00 247.07 249.42 245.97 246.54   18503200
# 5311 2025-09-29 00:00:00-04:00 247.85 251.15 242.77 244.05   32505800
# 5312 2025-09-30 00:00:00-04:00 242.81 243.29 239.25 243.10   34724300
# 5313 2025-10-01 00:00:00-04:00 240.75 246.30 238.61 244.90   31635500
#
#       Dividends  Stock Splits
# 0          0.00          0.00
# 1          0.00          0.00
# 2          0.00          0.00
# 3          0.00          0.00
# 4          0.00          0.00
# ...         ...           ...
# 5309       0.00          0.00
# 5310       0.00          0.00
# 5311       0.00          0.00
# 5312       0.00          0.00
# 5313       0.00          0.00
#
# [5314 rows x 8 columns]

# %% [markdown]
# Przypisz dwie nowe kolumny do obiektu _google_ dodając kolumnę z aktualnym numerem miesiąca o nazwie _'Month'_ oraz z rokiem o nazwie _'Year'_.
#
# __Wskazówka:__ Użyj funkcji pd.DataFrame().df.year oraz pd.DataFrame().df.month

# %%
google['Year'] = google['Date'].dt.year
google['Month'] = google['Date'].dt.month
google
# Out:
#                           Date   Open   High    Low  Close     Volume  \
# 0    2004-08-19 00:00:00-04:00   2.49   2.59   2.38   2.49  893181924
# 1    2004-08-20 00:00:00-04:00   2.51   2.71   2.50   2.69  456686856
# 2    2004-08-23 00:00:00-04:00   2.75   2.82   2.71   2.72  365122512
# 3    2004-08-24 00:00:00-04:00   2.76   2.77   2.57   2.61  304946748
# 4    2004-08-25 00:00:00-04:00   2.61   2.68   2.58   2.63  183772044
# ...                        ...    ...    ...    ...    ...        ...
# 5309 2025-09-25 00:00:00-04:00 244.40 246.49 240.74 245.79   31020400
# 5310 2025-09-26 00:00:00-04:00 247.07 249.42 245.97 246.54   18503200
# 5311 2025-09-29 00:00:00-04:00 247.85 251.15 242.77 244.05   32505800
# 5312 2025-09-30 00:00:00-04:00 242.81 243.29 239.25 243.10   34724300
# 5313 2025-10-01 00:00:00-04:00 240.75 246.30 238.61 244.90   31635500
#
#       Dividends  Stock Splits  Year  Month
# 0          0.00          0.00  2004      8
# 1          0.00          0.00  2004      8
# 2          0.00          0.00  2004      8
# 3          0.00          0.00  2004      8
# 4          0.00          0.00  2004      8
# ...         ...           ...   ...    ...
# 5309       0.00          0.00  2025      9
# 5310       0.00          0.00  2025      9
# 5311       0.00          0.00  2025      9
# 5312       0.00          0.00  2025      9
# 5313       0.00          0.00  2025     10
#
# [5314 rows x 10 columns]

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 44
# Policz średnią cenę zamknięcia (_Close_) dla poszczególnego roku (pogrupuj dane po roku - kolumna _Year_ i następnie policz wartość średnią).
#
# __Wskazówka:__ Użyj funkcji pd.DataFrame().groupby()

# %%
google.groupby('Year')['Close'].mean()
# Out:
# Year
# 2004     3.77
# 2005     6.90
# 2006    10.22
# 2007    13.39
# 2008    11.55
# 2009    10.93
# 2010    13.31
# 2011    14.14
# 2012    15.98
# 2013    21.98
# 2014    28.21
# 2015    30.79
# 2016    37.90
# 2017    46.67
# 2018    55.72
# 2019    59.15
# 2020    73.44
# 2021   123.37
# 2022   113.97
# 2023   117.98
# 2024   162.88
# 2025   185.14
# Name: Close, dtype: float64

# %% [markdown]
# Otrzymane wartości przedstaw na wykresie wykorzystując metodę _plot()_.

# %%
google.groupby('Year')['Close'].mean().plot();

# %% [markdown]
# Policz średnią cenę zamknięcia (_Close_) dla miesiąca (pogrupuj dane po miesiącu - kolumna _Month_ i następnie policz wartość średnią).

# %%
google.groupby('Month')['Close'].mean()
# Out:
# Month
# 1    51.62
# 2    51.71
# 3    50.12
# 4    51.36
# 5    52.91
# 6    53.07
# 7    56.51
# 8    56.23
# 9    56.55
# 10   48.72
# 11   49.65
# 12   50.40
# Name: Close, dtype: float64

# %% [markdown]
# Otrzymane wartości przedstaw na wykresie wykorzystując metodę _plot()_.
# Zauważ, które miesiące mogą wskazywać na słabsze okresy na giełdzie.

# %%
google.groupby('Month')['Close'].mean().plot();

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 45
# Pogrupuj dane z obiektu _google_ na poziomie roku i miesiąca. Następnie policz wartość średnią.

# %%
google.groupby(['Year', 'Month'])['Close'].mean()
# Out:
# Year  Month
# 2004  8         2.62
#       9         2.81
#       10        3.81
#       11        4.41
#       12        4.52
#                ...
# 2025  6       172.35
#       7       184.77
#       8       201.91
#       9       242.49
#       10      244.90
# Name: Close, Length: 255, dtype: float64

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 46
# Znajdź indeks dla którego kolumna _Close_ przyjmuje wartość największą.
#
# __Wskazówka:__ Użyj funkcji pd.DataFrame().argmax()

# %%
google['Close'].argmax()
# Out:
# np.int64(5305)

# %% [markdown]
# Wytnij wiersz dla tego indeksu z obiektu _google_ jako obiekt DataFrame. Odczytaj datę.

# %%
google.iloc[[google['Close'].argmax()]]
# Out:
#                           Date   Open   High    Low  Close    Volume  \
# 5305 2025-09-19 00:00:00-04:00 253.25 256.00 251.81 254.72  55571400
#
#       Dividends  Stock Splits  Year  Month
# 5305       0.00          0.00  2025      9

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 47
# Z obiektu _google_ wytnij kolumny _Date_, _Open_, _Close_, _Volume_.
# Nie zmieniaj pierwotnego obiektu _google_!

# %%
google[['Date', 'Open', 'Close', 'Volume']]
# Out:
#                           Date   Open  Close     Volume
# 0    2004-08-19 00:00:00-04:00   2.49   2.49  893181924
# 1    2004-08-20 00:00:00-04:00   2.51   2.69  456686856
# 2    2004-08-23 00:00:00-04:00   2.75   2.72  365122512
# 3    2004-08-24 00:00:00-04:00   2.76   2.61  304946748
# 4    2004-08-25 00:00:00-04:00   2.61   2.63  183772044
# ...                        ...    ...    ...        ...
# 5309 2025-09-25 00:00:00-04:00 244.40 245.79   31020400
# 5310 2025-09-26 00:00:00-04:00 247.07 246.54   18503200
# 5311 2025-09-29 00:00:00-04:00 247.85 244.05   32505800
# 5312 2025-09-30 00:00:00-04:00 242.81 243.10   34724300
# 5313 2025-10-01 00:00:00-04:00 240.75 244.90   31635500
#
# [5314 rows x 4 columns]

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 48
# Ustaw z powrotem indeks dla kolumny _Date_. Wyświetl obiekt _google_.

# %%
google = google.set_index('Date')
google
# Out:
#                             Open   High    Low  Close     Volume  Dividends  \
# Date
# 2004-08-19 00:00:00-04:00   2.49   2.59   2.38   2.49  893181924       0.00
# 2004-08-20 00:00:00-04:00   2.51   2.71   2.50   2.69  456686856       0.00
# 2004-08-23 00:00:00-04:00   2.75   2.82   2.71   2.72  365122512       0.00
# 2004-08-24 00:00:00-04:00   2.76   2.77   2.57   2.61  304946748       0.00
# 2004-08-25 00:00:00-04:00   2.61   2.68   2.58   2.63  183772044       0.00
# ...                          ...    ...    ...    ...        ...        ...
# 2025-09-25 00:00:00-04:00 244.40 246.49 240.74 245.79   31020400       0.00
# 2025-09-26 00:00:00-04:00 247.07 249.42 245.97 246.54   18503200       0.00
# 2025-09-29 00:00:00-04:00 247.85 251.15 242.77 244.05   32505800       0.00
# 2025-09-30 00:00:00-04:00 242.81 243.29 239.25 243.10   34724300       0.00
# 2025-10-01 00:00:00-04:00 240.75 246.30 238.61 244.90   31635500       0.00
#
#                            Stock Splits  Year  Month
# Date
# 2004-08-19 00:00:00-04:00          0.00  2004      8
# 2004-08-20 00:00:00-04:00          0.00  2004      8
# 2004-08-23 00:00:00-04:00          0.00  2004      8
# 2004-08-24 00:00:00-04:00          0.00  2004      8
# 2004-08-25 00:00:00-04:00          0.00  2004      8
# ...                                 ...   ...    ...
# 2025-09-25 00:00:00-04:00          0.00  2025      9
# 2025-09-26 00:00:00-04:00          0.00  2025      9
# 2025-09-29 00:00:00-04:00          0.00  2025      9
# 2025-09-30 00:00:00-04:00          0.00  2025      9
# 2025-10-01 00:00:00-04:00          0.00  2025     10
#
# [5314 rows x 9 columns]

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 49
# Usuń na stałe kolumny _Year_ , _Month_ , _Dividends_ i _Stock Splits_ z obiektu _google_. Wyświetl obiekt _google_.
#
# __Wskazówka:__ Użyj funkcji pd.DataFrame().drop()

# %%
google = google.drop(columns=['Year', 'Month', 'Dividends', 'Stock Splits'])
google
# Out:
#                             Open   High    Low  Close     Volume  Dividends  \
# Date
# 2004-08-19 00:00:00-04:00   2.49   2.59   2.38   2.49  893181924       0.00
# 2004-08-20 00:00:00-04:00   2.51   2.71   2.50   2.69  456686856       0.00
# 2004-08-23 00:00:00-04:00   2.75   2.82   2.71   2.72  365122512       0.00
# 2004-08-24 00:00:00-04:00   2.76   2.77   2.57   2.61  304946748       0.00
# 2004-08-25 00:00:00-04:00   2.61   2.68   2.58   2.63  183772044       0.00
# ...                          ...    ...    ...    ...        ...        ...
# 2025-09-25 00:00:00-04:00 244.40 246.49 240.74 245.79   31020400       0.00
# 2025-09-26 00:00:00-04:00 247.07 249.42 245.97 246.54   18503200       0.00
# 2025-09-29 00:00:00-04:00 247.85 251.15 242.77 244.05   32505800       0.00
# 2025-09-30 00:00:00-04:00 242.81 243.29 239.25 243.10   34724300       0.00
# 2025-10-01 00:00:00-04:00 240.75 246.30 238.61 244.90   31635500       0.00
#
#                            Stock Splits
# Date
# 2004-08-19 00:00:00-04:00          0.00
# 2004-08-20 00:00:00-04:00          0.00
# 2004-08-23 00:00:00-04:00          0.00
# 2004-08-24 00:00:00-04:00          0.00
# 2004-08-25 00:00:00-04:00          0.00
# ...                                 ...
# 2025-09-25 00:00:00-04:00          0.00
# 2025-09-26 00:00:00-04:00          0.00
# 2025-09-29 00:00:00-04:00          0.00
# 2025-09-30 00:00:00-04:00          0.00
# 2025-10-01 00:00:00-04:00          0.00
#
# [5314 rows x 7 columns]

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 50
# Przypisz polskie nazwy kolumn (bez polskich znaków):
# * Open -> Otwarcie
# * High -> Najwyzszy
# * Low -> Najnizszy
# * Close -> Zamkniecie
# * Volume -> Wolumen
#
# do obiektu _google_. Wyświetl obiekt _google_.

# %%
google.columns = ['Otwarcie', 'Najwyzszy', 'Najnizszy', 'Zamkniecie', 'Wolumen']
google
# Out:
#             Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# Date
# 2024-05-31    171.86     173.06     169.44      172.50  37638876
# 2024-05-30    175.20     175.22     171.79      172.11  22958677
# 2024-05-29    175.43     176.84     174.72      175.90  23388693
# 2024-05-28    174.45     177.27     174.37      176.40  20572157
# 2024-05-24    174.98     175.77     173.65      174.99  16579438
# ...              ...        ...        ...         ...       ...
# 2019-06-10     53.85      54.74      53.76       54.14  28509280
# 2019-06-07     52.71      53.67      52.56       53.42  43827140
# 2019-06-06     52.31      52.50      51.78       52.39  29020520
# 2019-06-05     52.75      52.84      51.65       52.23  46988720
# 2019-06-04     52.22      52.92      51.80       52.72  60511280
#
# [1258 rows x 5 columns]
